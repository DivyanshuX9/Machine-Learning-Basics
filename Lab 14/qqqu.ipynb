# %%
from sklearn.naive_bayes import GaussianNB ,MultinomialNB , BernoulliNB

# %%
from slaern.tree import DecisionTreeClassifier

model=DecisionTreeClassifier(criterion="entropy')

# %%
plt.figure(figuresize=(12,8))
plot_tree(model,
feature_names=X.coluns,
class_name=True,
fi;;ed=True)

plt.show()

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel='rbf')

svm.fit(X_train,y_train)

y_pred=svm.predict(X_test)

# %%
X=(X-X.mean())/X.std()
som=MiniSom(x=5,y=5,input_len=X.shape[1],sigma=1,learning_rate=0.5)

som.train_random(X.values,100)

mapping=[som.winner(x) for x in X.values]
